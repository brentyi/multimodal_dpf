# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import time

from lib import dpf, panda_models, panda_datasets, panda_training
from lib.utils import file_utils, torch_utils, misc_utils

print(torch.__version__, np.__version__)
# Out:
# 1.3.1 1.16.4

# %%
# Experiment configuration
experiment_name = "dpf_vision_only"
dataset_args = {
    'use_proprioception': False,
    'use_haptics': False,
    'use_vision': True,
    'vision_interval': 10,
}

# %%
# Create models & training buddy

dynamics_model = panda_models.PandaSimpleDynamicsModel(state_noise=(0.05))
measurement_model = panda_models.PandaMeasurementModel(units=32)

pf_model = dpf.ParticleFilterNetwork(dynamics_model, measurement_model)

buddy = torch_utils.TrainingBuddy(
    experiment_name,
    pf_model,
    optimizer_names=["e2e", "dynamics", "measurement"],
    log_dir="logs/pf",
    checkpoint_dir="checkpoints/pf"
)
# Out:
# Using device: cuda
# Loaded checkpoint from path: checkpoints/pf/dpf_vision_only-0000000000481155.ckpt

# %% [markdown]
# # Dynamics Model Pre-Training

# %%
# dynamics_trainset = panda_datasets.PandaDynamicsDataset(
#     "data/pull-test.hdf5",
#     "data/push-test.hdf5",
#     **dataset_args
# )

# %%
# dataloader = torch.utils.data.DataLoader(dynamics_trainset, batch_size=256, shuffle=True, num_workers=2)

# for i in range(0):
#     print("Training epoch", i)
#     panda_training.train_dynamics(buddy, pf_model, dataloader, log_interval=10)
#     print()

# %% [markdown]
# # Measurement Model Pre-Training

# %%
measurement_trainset = panda_datasets.PandaMeasurementDataset(
    ("data/pull-test.hdf5", 1000),
    ("data/push-test.hdf5", 1000),
    std_dev=0.15,
    **dataset_args
)
# Out:
# Progress: [####################] 100.0%

# %%
measurement_trainset_loader = torch.utils.data.DataLoader(measurement_trainset, batch_size=64, shuffle=True, num_workers=16)
for i in range(3):
    print("Training epoch", i)
    panda_training.train_measurement(buddy, pf_model, measurement_trainset_loader, log_interval=100)
    print()

# measurement_trainset_loader = torch.utils.data.DataLoader(measurement_trainset, batch_size=64, shuffle=True, num_workers=2)
# for i in range(1):
#     print("Training epoch", i)
#     panda_training.train_measurement(buddy, pf_model, measurement_trainset_loader, log_interval=100)
#     print()

# measurement_trainset_loader = torch.utils.data.DataLoader(measurement_trainset, batch_size=256, shuffle=True, num_workers=2)
# for i in range(1):
#     print("Training epoch", i)
#     panda_training.train_measurement(buddy, pf_model, measurement_trainset_loader, log_interval=100)
#     print()
# Out:
# ..........[0.55%]..........[1.09%]..........[1.64%]..........[2.18%]..........[2.73%]..........[3.28%]..........[3.82%]..........[4.37%]..........[4.92%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000010000.ckpt
# .[5.46%]..........[6.01%]..........[6.56%]..........[7.10%]..........[7.65%]..........[8.20%]..........[8.74%]..........[9.29%]..........[9.83%]..........[10.38%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000020000.ckpt
# .[10.93%]..........[11.47%]..........[12.02%]..........[12.57%]..........[13.11%]..........[13.66%]..........[14.21%]..........[14.75%]..........[15.30%]..........[15.84%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000
].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000350000.ckpt
# .[91.23%]..........[91.78%]..........[92.33%]..........[92.87%]..........[93.42%]..........[93.97%]..........[94.51%]..........[95.06%]..........[95.61%]..........[96.15%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000360000.ckpt
# .[96.70%]..........[97.24%]..........[97.79%]..........[98.34%]..........[98.88%]..........[99.43%]..........[99.98%]Epoch loss: 1.3502289
#
# Training epoch 2
# ..........[0.52%]..........[1.07%]..........[1.62%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000370000.ckpt
# .[2.16%]..........[2.71%]..........[3.25%]..........[3.80%]..........[4.35%]..........[4.89%]..........[5.44%]..........[5.99%]..........[6.53%]..........[7.08%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000380000.ckpt
# .[7.63%]..........[8.17%]..........[8.72%]..........[9.27%]..........[9.81%]..........[10.36%]..........[10.90%]..........[11.45%]..........[12.00%]..........[12.54%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000390000.ckpt
# .[13.09%]..........[13.64%]..........[14.18%]..........[14.73%]..........[15.28%]..........[15.82%]..........[16.37%]..........[16.91%]..........[17.46%]..........[18.01%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000400000.ckpt
# .[18.55%]..........[19.10%]..........[19.65%]..........[20.19%]..........[20.74%]..........[21.29%]..........[21.83%]..........[22.38%]..........[22.92%]..........[23.47%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000410000.ckpt
# .[24.02%]..........[24.56%]..........[25.11%]..........[25.66%]..........[26.20%]..........[26.75%]..........[27.30%]..........[27.84%]..........[28.39%]..........[28.93%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000420000.ckpt
# .[29.48%]..........[30.03%]..........[30.57%]..........[31.12%]..........[31.67%]..........[32.21%]..........[32.76%]..........[33.31%]..........[33.85%]..........[34.40%].........Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000430000.ckpt
# .[34.95%]..........[35.49%]..........[36.04%]..........[36.58%]...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-813e5295910c> in <module>()
#       2 for i in range(3):
#       3     print("Training epoch", i)
# ----> 4     panda_training.train_measurement(buddy, pf_model, measurement_trainset_loader, log_interval=100)
#       5     print()
#       6
#
# ~/dpf/lib/panda_training.py in train_measurement(buddy, pf_model, dataloader, log_interval)
#      63         noisy_states = noisy_states[:, np.newaxis, :]
#      64         pred_likelihoods = pf_model.measurement_model(
# ---> 65             observations, noisy_states)
#      66         assert len(pred_likelihoods.shape) == 2
#      67         pred_likelihoods = pred_likelihoods.squeeze(dim=1)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/dpf/lib/panda_models.py in forward(self, observations, states)
#     276
#     277         # (N, M, units * 4) => (N, M, 1)
# --> 278         log_likelihoods = self.shared_layers(merged_features)
#     279         assert log_likelihoods.shape == (N, M, 1)
#     280
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/dpf/lib/resblocks.py in forward(self, x)
#      22         x = self.block1(x)
#      23         x = self.activation(x)
# ---> 24         x = self.block2(x)
#      25         assert x.shape[0] == residual.shape[0]
#      26         x += residual
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/traceback.py in format_stack(f, limit)
#     191     if f is None:
#     192         f = sys._getframe().f_back
# --> 193     return format_list(extract_stack(f, limit=limit))
#     194
#     195
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/traceback.py in format_list(extracted_list)
#      35     whose source text line is not None.
#      36     """
# ---> 37     return StackSummary.from_list(extracted_list).format()
#      38
#      39 #
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/traceback.py in format(self)
#     414                 frame.filename, frame.lineno, frame.name))
#     415             if frame.line:
# --> 416                 row.append('    {}\n'.format(frame.line.strip()))
#     417             if frame.locals:
#     418                 for name, value in sorted(frame.locals.items()):
#
# KeyboardInterrupt:

# %%
buddy.save_checkpoint(label="before_e2e_training")
# Out:
# Saved checkpoint to path: checkpoints/pf/dpf_vision_only-before_e2e_training.ckpt

# %% [markdown]
# # End-to-end Training

# %%
# Create end-to-end dataset

e2e_trainset = panda_datasets.PandaParticleFilterDataset(
    ("data/pull-test.hdf5", 1000),
    ("data/push-test.hdf5", 1000),
    subsequence_length=20,
    particle_count=50,
    particle_variances=(.2,),
    **dataset_args
)
# Out:
# Parsed data: 20570 active, 8605 inactive
# Keeping: 8605

# %%
##### Train end-to-end
pf_model.dynamics_model.state_noise = (0.1)

pf_model.freeze_measurement_model = False
pf_model.freeze_dynamics_model = True

# e2e_trainset_loader = torch.utils.data.DataLoader(e2e_trainset, batch_size=32, shuffle=True, num_workers=2)
# for i in range(3):
#     print("Training epoch", i)
#     panda_training.train_e2e(buddy, pf_model, e2e_trainset_loader, loss_type="mse", log_interval=100)

e2e_trainset_loader = torch.utils.data.DataLoader(e2e_trainset, batch_size=64, shuffle=True, num_workers=2)
for i in range(3):
    print("Training epoch", i)
    panda_training.train_e2e(buddy, pf_model, e2e_trainset_loader, loss_type="mse", log_interval=100)
# Out:
# Training epoch 0
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Epoch loss: 0.0021475314
# Training epoch 1
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Epoch loss: 0.002096055
# Training epoch 2
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Epoch loss: 0.002085834

# %%
buddy.save_checkpoint()
# Out:
# Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000481155.ckpt

# %% [markdown]
# # Model eval

# %%
eval_trajectories_list = []

def load_trajectories(label, validation, include_pull, include_push, max_count=10):
    if validation:
        # Validation set
        files = [
            ("data/pull-test-small.hdf5", max_count),
            ("data/push-test-small.hdf5", max_count)
        ]
    else:
        # Training set
        files = [
            ("data/pull-test.hdf5", max_count),
            ("data/push-test.hdf5", max_count)
        ]
    
    filtered_files = []
    if include_pull:
        filtered_files.append(files[0])
    if include_push:
        filtered_files.append(files[1])

    trajectories = panda_datasets.load_trajectories(
        *filtered_files,
        **dataset_args
    )
    eval_trajectories_list.append((label, trajectories))

load_trajectories("Validation all", validation=True, include_pull=True, include_push=True)
load_trajectories("Validation pull", validation=True, include_pull=True, include_push=False)
load_trajectories("Validation push", validation=True, include_pull=False, include_push=True)

load_trajectories("Training all", validation=False, include_pull=True, include_push=True)
load_trajectories("Training pull", validation=False, include_pull=True, include_push=False)
load_trajectories("Training push", validation=False, include_pull=False, include_push=True)

# %% [markdown]
# ### Final Model

# %%
pf_model.dynamics_model.state_noise = (0.1)

# Evaluate final model
for label, trajectories in eval_trajectories_list:
    print("###############################")
    print("###############################")
    print("##", label)
    print("###############################")
    print("###############################")
    pred, actual = panda_training.rollout(pf_model, trajectories, start_time=0, max_timesteps=1000, particle_count=200, noisy_dynamics=True)
    panda_training.vis_rollout(pred, actual)
# Out:
# ###############################
# ###############################
# ## Validation all
# ###############################
# ###############################
# ...................................
# (20, 352, 1)
# Position MSE:  0.0023389237
# ###############################
# ###############################
# ## Validation pull
# ###############################
# ###############################
# ................................................................
# (10, 649, 1)
# Position MSE:  0.0025867086
# ###############################
# ###############################
# ## Validation push
# ###############################
# ###############################
# ...................................
# (10, 352, 1)
# Position MSE:  0.0019270646
# ###############################
# ###############################
# ## Training all
# ###############################
# ###############################
# .......................................
# (20, 394, 1)
# Position MSE:  0.0017506515
# ###############################
# ###############################
# ## Training pull
# ###############################
# ###############################
# ............................................................................
# (10, 769, 1)
# Position MSE:  0.0024980013
# ###############################
# ###############################
# ## Training push
# ###############################
# ###############################
# .......................................
# (10, 394, 1)
# Position MSE:  0.0014121305

# %% [markdown]
# ### Model without end-to-end training

# %%
# Back up model
buddy.save_checkpoint()

# Load the pre-end-to-end-training version of the model & evaluate
buddy.load_checkpoint(label="before_e2e_training")
for label, trajectories in eval_trajectories_list:
    print("###############################")
    print("###############################")
    print("##", label)
    print("###############################")
    print("###############################")
    pred, actual = panda_training.rollout(pf_model, trajectories, start_time=0, max_timesteps=1000, particle_count=200, noisy_dynamics=True)
    panda_training.vis_rollout(pred, actual)

# Restore model
buddy.load_checkpoint()
# Out:
# Saved checkpoint to path: checkpoints/pf/dpf_vision_only-0000000000481155.ckpt
# checkpoints/pf/dpf_vision_only-before_e2e_training.ckpt
# Loaded checkpoint from path: checkpoints/pf/dpf_vision_only-before_e2e_training.ckpt
# ###############################
# ###############################
# ## Validation all
# ###############################
# ###############################
# ...................................
# (20, 352, 1)
# Position MSE:  0.0023345307
# ###############################
# ###############################
# ## Validation pull
# ###############################
# ###############################
# ................................................................
# (10, 649, 1)
# Position MSE:  0.0026478665
# ###############################
# ###############################
# ## Validation push
# ###############################
# ###############################
# ...................................
# (10, 352, 1)
# Position MSE:  0.0020128435
# ###############################
# ###############################
# ## Training all
# ###############################
# ###############################
# .......................................
# (20, 394, 1)
# Position MSE:  0.0016837434
# ###############################
# ###############################
# ## Training pull
# ###############################
# ###############################
# ............................................................................
# (10, 769, 1)
# Position MSE:  0.0024629848
# ###############################
# ###############################
# ## Training push
# ###############################
# ###############################
# .......................................
# (10, 394, 1)
# Position MSE:  0.0015026764
# Loaded checkpoint from path: checkpoints/pf/dpf_vision_only-0000000000481155.ckpt
